# %% [markdown]
# <a href="https://colab.research.google.com/github/taguezem/detect-skills-using-machine-learning/blob/main/testDetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/Example_Technical_Skills.csv')

print(df.to_string())
# Out:
#                              Technology Skills
# 0                          SAP Fiori Developer
# 1        Oracle Instance Management & Strategy
# 2                 Boomi Master Data Management
# 3        Digital Manufacturing on Cloud ( DMC)
# 4                                       DevOps
# 5                                       CA SAM
# 6                                    OpenShift
# 7                        Acxiom Data Analytics
# 8                        SAP Digital Boardroom
# 9                                Seeburger BIS
# 10                    SAP Transport Management
# 11                         PeopleSoft Workflow
# 12                               NICE Actimize
# 13                     Oracle - Access Manager
# 14       SAP Electronic Data Interchange (EDI)
# 15                         Ideas crowdsourcing
# 16               PeopleSoft Workforce Planning
# 17                                SAP Benefits
# 18                ONESOURCE R&D Credit Manager
# ...

# %%
df1 = pd.read_csv('/content/Raw_Skills_Dataset.csv')

print(df1.head(10).to_string())
# Out:
#                    RAW DATA
# 0                  What ifs
# 1                 seniority
# 2               familiarity
# 3           functionalities
# 4                   Lambdas
# 5              Java Streams
# 6  Object Oriented analysis
# 7      Relational Databases
# 8                       SQL
# 9                       ORM

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')
